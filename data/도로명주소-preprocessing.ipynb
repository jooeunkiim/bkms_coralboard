# %%
import pandas as pd

# %%
data = pd.DataFrame()
for i in range(25):
    add = pd.read_excel('./도로명주소/도로명정보조회 ('+str(i)+').xls', header=1)
    data = pd.concat([data, add])

# %%
data
# Out:
#       시군구    도로명번호       도로명                           로마자표기  읍면동일련번호    시도명  \
# 0     강남구  1000033  용인서울고속도로         Yongin Seoul Expressway        0  서울특별시
# 1     강남구  2000003     남부순환로                 Nambusunhwan-ro        0  서울특별시
# 2     강남구  2000003     남부순환로                 Nambusunhwan-ro        4  서울특별시
# 3     강남구  2000003     남부순환로                 Nambusunhwan-ro        1  서울특별시
# 4     강남구  2000003     남부순환로                 Nambusunhwan-ro        2  서울특별시
# ...   ...      ...       ...                             ...      ...    ...
# 1224  중랑구  4859029  양원역로14가길         Yangwonyeok-ro 14ga-gil        1  서울특별시
# 1225  중랑구  4859030  양원역로14나길         Yangwonyeok-ro 14na-gil        0  서울특별시
# 1226  중랑구  4859030  양원역로14나길         Yangwonyeok-ro 14na-gil        1  서울특별시
# 1227  중랑구  4859671  중랑천서자전거길   Jungnangcheonseojajeongeo-gil        0  서울특별시
# 1228  중랑구  4859672  중랑천동자전거길  Jungnangcheondongjajeongeo-gil        0  서울특별시
#
#      시군구명  읍면동구분  읍면동코드 읍면동명
# ...

# %%
data.to_csv('road_name.csv', index=False)
